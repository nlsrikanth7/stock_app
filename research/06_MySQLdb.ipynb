# %%
import sqlalchemy
import pymysql
from sqlalchemy.schema import CreateSchema
from sqlalchemy import create_engine

# %%
#for connecting to mysql
pymysql.install_as_MySQLdb()

# %%
#create 3 schemas 
# indices  = ['Nifty50', 'RTSI', 'Bovespa']
indices  = ['Nifty50', 'RTSI']

# %%
# Define a function to create these above mentioned schemas, use this for a single schema creation
# def schemacreator(index):
#     engine = sqlalchemy.create_engine('mysql://root:Shrikanth_1@localhost:3306/')
#     engine.execute(sqlalchemy.schema.CreateSchema(index))
#     engine

# %%
def schemacreator(index):
    engine = sqlalchemy.create_engine('mysql://root:Shrikanth_1@localhost:3306/')
    with engine.connect() as connection:
        connection.execute(CreateSchema(index, if_not_exists=True))
        connection.commit()

# %%
#Call the function to create the schemas
for index in indices:
    schemacreator(index)

# %%
import pandas as pd

# %%
nifty = pd.read_html('https://en.wikipedia.org/wiki/NIFTY_50')[2]
rts = pd.read_html('https://en.wikipedia.org/wiki/RTS_Index')[1]
# bovespa = pd.read_html('https://en.wikipedia.org/wiki/List_of_companies_listed_on_B3')[0]

# %%
nifty
# Out:
#                        Company Name      Symbol              Sector[16]
# 0                 Adani Enterprises    ADANIENT             Diversified
# 1                 Adani Ports & SEZ  ADANIPORTS          Infrastructure
# 2                  Apollo Hospitals  APOLLOHOSP              Healthcare
# 3                      Asian Paints  ASIANPAINT       Consumer Durables
# 4                         Axis Bank    AXISBANK                 Banking
# 5                        Bajaj Auto  BAJAJ-AUTO              Automobile
# 6                     Bajaj Finance  BAJFINANCE      Financial Services
# 7                     Bajaj Finserv  BAJAJFINSV      Financial Services
# 8                  Bharat Petroleum        BPCL      Energy - Oil & Gas
# 9                     Bharti Airtel  BHARTIARTL       Telecommunication
# 10             Britannia Industries   BRITANNIA          Consumer Goods
# 11                            Cipla       CIPLA         Pharmaceuticals
# 12                       Coal India   COALINDIA           Energy - Coal
# 13              Divi's Laboratories    DIVISLAB         Pharmaceuticals
# 14         Dr. Reddy's Laboratories     DRREDDY         Pharmaceuticals
# 15                    Eicher Motors   EICHERMOT              Automobile
# 16                Grasim Industries      GRASIM               Materials
# 17                          HCLTech     HCLTECH  Information Technology
# 18                        HDFC Bank    HDFCBANK                 Banking
# 19                        HDFC Life    HDFCLIFE      Financial Services
# 20                    Hero MotoCorp  HEROMOTOCO              Automobile
# 21              Hindalco Industries    HINDALCO                  Metals
# 22               Hindustan Unilever  HINDUNILVR          Consumer Goods
# 23                       ICICI Bank   ICICIBANK                 Banking
# 24                    IndusInd Bank  INDUSINDBK                 Banking
# 25                          Infosys        INFY  Information Technology
# 26                              ITC         ITC          Consumer Goods
# 27                        JSW Steel    JSWSTEEL                  Metals
# 28              Kotak Mahindra Bank   KOTAKBANK                 Banking
# 29                  Larsen & Toubro          LT            Construction
# 30                      LTIMindtree        LTIM  Information Technology
# 31              Mahindra & Mahindra         M&M              Automobile
# 32                    Maruti Suzuki      MARUTI              Automobile
# 33                     Nestlé India   NESTLEIND          Consumer Goods
# 34                             NTPC        NTPC          Energy - Power
# 35  Oil and Natural Gas Corporation        ONGC      Energy - Oil & Gas
# 36                       Power Grid   POWERGRID          Energy - Power
# 37              Reliance Industries    RELIANCE             Diversified
# 38       SBI Life Insurance Company     SBILIFE      Financial Services
# 39              State Bank of India        SBIN                 Banking
# 40                       Sun Pharma   SUNPHARMA         Pharmaceuticals
# 41                      Tata Motors  TATAMOTORS              Automobile
# 42                       Tata Steel   TATASTEEL                  Metals
# 43        Tata Consultancy Services         TCS  Information Technology
# 44           Tata Consumer Products  TATACONSUM          Consumer Goods
# 45                    Tech Mahindra       TECHM  Information Technology
# 46                    Titan Company       TITAN       Consumer Durables
# 47                 UltraTech Cement  ULTRACEMCO               Materials
# 48                              UPL         UPL               Chemicals
# 49                            Wipro       WIPRO  Information Technology

# %%
nifty = nifty.Symbol.to_list()
nifty
# Out:
# ['ADANIENT',
#  'ADANIPORTS',
#  'APOLLOHOSP',
#  'ASIANPAINT',
#  'AXISBANK',
#  'BAJAJ-AUTO',
#  'BAJFINANCE',
#  'BAJAJFINSV',
#  'BPCL',
#  'BHARTIARTL',
#  'BRITANNIA',
#  'CIPLA',
#  'COALINDIA',
#  'DIVISLAB',
#  'DRREDDY',
#  'EICHERMOT',
#  'GRASIM',
#  'HCLTECH',
#  'HDFCBANK',
#  'HDFCLIFE',
#  'HEROMOTOCO',
#  'HINDALCO',
#  'HINDUNILVR',
#  'ICICIBANK',
#  'INDUSINDBK',
#  'INFY',
#  'ITC',
#  'JSWSTEEL',
#  'KOTAKBANK',
#  'LT',
#  'LTIM',
#  'M&M',
#  'MARUTI',
#  'NESTLEIND',
#  'NTPC',
#  'ONGC',
#  'POWERGRID',
#  'RELIANCE',
#  'SBILIFE',
#  'SBIN',
#  'SUNPHARMA',
#  'TATAMOTORS',
#  'TATASTEEL',
#  'TCS',
#  'TATACONSUM',
#  'TECHM',
#  'TITAN',
#  'ULTRACEMCO',
#  'UPL',
#  'WIPRO']

# %%
rts
# Out:
#                               Company Ticker symbol  \
# 0                         AFK Sistema          AFKS
# 1                            Aeroflot          AFLT
# 2                             Rusagro          AGRO
# 3                               Acron          AKRN
# 4                               Lenta          LNTA
# 5               Credit Bank of Moscow          CBOM
# 6                          Detsky Mir          DSKY
# 7                           SeverStal          CHMF
# 8                                DIXY          DIXY
# 9                             FGC UES          FEES
# 10                            Gazprom          GAZP
# 11                     Norilsk Nickel          GMKN
# 12                           RusHydro          HYDR
# 13                          Inter RAO          IRAO
# 14                             Lukoil          LKOH
# 15                          LSR Group          LSRG
# 16  Magnitogorsk Iron and Steel Works          MAGN
# 17                            MegaFon          MFON
# 18                        OJSC Magnit          MGNT
# 19                    Moscow Exchange          MOEX
# 20                          Mosenergo          MSNG
# 21                             Mechel          MTLR
# 22                             Alrosa          ALRS
# 23                 Mobile TeleSystems          MTSS
# 24                            M.video          MVID
# 25                  Novolipetsk Steel          NLMK
# 26   Novorossiysk Commercial Sea Port          NMPT
# 27                            Novatek          NVTK
# 28                           PhosAgro          PHOR
# 29                          PIK Group          PIKK
# 30                        Polyus Gold          PLZL
# 31            Polymetal International          POLY
# 32                            Rosneft          ROSN
# 33                            Rosseti          RSTI
# 34                         Rostelecom          RTKM
# 35                              Rusal         RUALR
# 36                                SFI          EPLN
# 37                           Sberbank          SBER
# 38                           Sberbank         SBERP
# 39                     Surgutneftegas          SNGS
# 40                     Surgutneftegas         SNGSP
# 41                            Tatneft          TATN
# 42                            Tatneft         TATNP
# 43                            OAO TMK          TRMK
# 44                          Transneft         TRNFP
# 45                             Unipro          UPRO
# 46                           Russneft          RNFT
# 47               United Wagon Company          UWGN
# 48                           VTB Bank          VTBR
# 49                             Yandex          YNDX
#
#                           Stock type                 Industry
# 0                             Common             Conglomerate
# 1                             Common           Transportation
# 2                 Depositary receipt              Agriculture
# 3                             Common                Chemicals
# 4                 Depositary receipt                   Retail
# 5                             Common                  Banking
# 6                             Common                   Retail
# 7                             Common      Mining & Metallurgy
# 8                             Common                   Retail
# 9                             Common         Electric utility
# 10                            Common                Oil & gas
# 11                            Common      Mining & Metallurgy
# 12                            Common                   Energy
# 13                            Common                   Energy
# 14                            Common                Oil & gas
# 15                            Common  Real estate development
# 16                            Common               Metallurgy
# 17                            Common        Telecommunication
# 18                            Common                   Retail
# 19                            Common           Stock exchange
# 20                            Common                   Energy
# 21                            Common      Mining & Metallurgy
# 22                            Common                   Mining
# 23                            Common        Telecommunication
# 24                            Common                   Retail
# 25                            Common               Metallurgy
# 26                            Common           Transportation
# 27                            Common                Oil & gas
# 28                            Common                Chemicals
# 29                            Common  Real estate development
# 30                            Common                   Mining
# 31                            Common                   Mining
# 32                            Common                Oil & gas
# 33                            Common         Electric utility
# 34                            Common        Telecommunication
# 35  Russian depositary receipt (RDR)                   Mining
# 36                            Common                  Leasing
# 37                            Common                  Banking
# 38                         Preferred                  Banking
# 39                            Common                Oil & gas
# 40                         Preferred                Oil & gas
# 41                            Common                Oil & gas
# 42                         Preferred                Oil & gas
# 43                            Common           Steel industry
# 44                         Preferred                Oil & gas
# 45                            Common         Electric utility
# 46                            Common                 Refining
# 47                            Common   Mechanical engineering
# 48                            Common                  Banking
# 49                            Common                 Internet

# %%
rts = rts['Ticker symbol'].to_list()
rts
# Out:
# ['AFKS',
#  'AFLT',
#  'AGRO',
#  'AKRN',
#  'LNTA',
#  'CBOM',
#  'DSKY',
#  'CHMF',
#  'DIXY',
#  'FEES',
#  'GAZP',
#  'GMKN',
#  'HYDR',
#  'IRAO',
#  'LKOH',
#  'LSRG',
#  'MAGN',
#  'MFON',
#  'MGNT',
#  'MOEX',
#  'MSNG',
#  'MTLR',
#  'ALRS',
#  'MTSS',
#  'MVID',
#  'NLMK',
#  'NMPT',
#  'NVTK',
#  'PHOR',
#  'PIKK',
#  'PLZL',
#  'POLY',
#  'ROSN',
#  'RSTI',
#  'RTKM',
#  'RUALR',
#  'EPLN',
#  'SBER',
#  'SBERP',
#  'SNGS',
#  'SNGSP',
#  'TATN',
#  'TATNP',
#  'TRMK',
#  'TRNFP',
#  'UPRO',
#  'RNFT',
#  'UWGN',
#  'VTBR',
#  'YNDX']

# %%
# bovespa

# %%
# bovespa = bovespa.Ticker.to_list()
# bovespa

# %%
# string comprehension
nifty = [i+'.NS' for i in nifty]
rts = [i+'.ME' for i in rts]
# bovespa = [i+'.SA' for i in bovespa]

# %%
nifty[0]
rts[0]
# bovespa[0]
# Out:
# 'Company.ME'

# %%
import yfinance as yf

# %%
yf.download(nifty[0], start='2023-05-20')
# Out:
# [*********************100%%**********************]  2 of 2 completed
# 2 Failed downloads:
# ['NAME.NS', 'COMPANY']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Empty DataFrame
# Columns: [(Adj Close, COMPANY), (Adj Close, NAME.NS), (Close, COMPANY), (Close, NAME.NS), (High, COMPANY), (High, NAME.NS), (Low, COMPANY), (Low, NAME.NS), (Open, COMPANY), (Open, NAME.NS), (Volume, COMPANY), (Volume, NAME.NS)]
# Index: []

# %%
#Create a dictonary called mapper
# mapper = {'Nifty50': nifty, 'Bovespa': bovespa, 'RTSI': rts}
mapper = {'Nifty50': nifty, 'RTSI': rts}

# %%
for symbol in mapper['Nifty50']:
    print(symbol)
# Out:
# ADANIENT.NS
# ADANIPORTS.NS
# APOLLOHOSP.NS
# ASIANPAINT.NS
# AXISBANK.NS
# BAJAJ-AUTO.NS
# BAJFINANCE.NS
# BAJAJFINSV.NS
# BPCL.NS
# BHARTIARTL.NS
# BRITANNIA.NS
# CIPLA.NS
# COALINDIA.NS
# DIVISLAB.NS
# DRREDDY.NS
# EICHERMOT.NS
# GRASIM.NS
# HCLTECH.NS
# HDFCBANK.NS
# HDFCLIFE.NS
# HEROMOTOCO.NS
# HINDALCO.NS
# HINDUNILVR.NS
# ICICIBANK.NS
# INDUSINDBK.NS
# INFY.NS
# ITC.NS
# JSWSTEEL.NS
# KOTAKBANK.NS
# LT.NS
# LTIM.NS
# M&M.NS
# MARUTI.NS
# NESTLEIND.NS
# NTPC.NS
# ONGC.NS
# POWERGRID.NS
# RELIANCE.NS
# SBILIFE.NS
# SBIN.NS
# SUNPHARMA.NS
# TATAMOTORS.NS
# TATASTEEL.NS
# TCS.NS
# TATACONSUM.NS
# TECHM.NS
# TITAN.NS
# ULTRACEMCO.NS
# UPL.NS
# WIPRO.NS

# %%
# Get the prices of each stock and load into mysql
for index in indices:
    engine = sqlalchemy.create_engine('mysql://root:Shrikanth_1@localhost:3306/'+index) # select the correct schema respectively
    for symbol in mapper[index]:
        df = yf.download(symbol, start = '2023-01-01')
        df = df.reset_index() # reset the index so datetime will be column and not index
        df.to_sql(symbol, engine)
# Out:
# [*********************100%%**********************]  1 of 2 completed
# 2 Failed downloads:
# ['NAME.NS', 'COMPANY']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/shrikanthnallapati/Projects/stock_app/research/06_MySQLdb.ipynb Cell 21 line 7
#       <a href='vscode-notebook-cell:/Users/shrikanthnallapati/Projects/stock_app/research/06_MySQLdb.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> df = yf.download(symbol, start = '2023-01-01')
#       <a href='vscode-notebook-cell:/Users/shrikanthnallapati/Projects/stock_app/research/06_MySQLdb.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a> df = df.reset_index() # reset the index so datetime will be column and not index
# ----> <a href='vscode-notebook-cell:/Users/shrikanthnallapati/Projects/stock_app/research/06_MySQLdb.ipynb#X26sZmlsZQ%3D%3D?line=6'>7</a> df.to_sql(symbol, engine)
#
# File ~/Projects/stock_app/stockapp/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Projects/stock_app/stockapp/lib/python3.11/site-packages/pandas/core/generic.py:3008, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2813 """
#    2814 Write records stored in a DataFrame to a SQL database.
#    2815
#    (...)
#    3004 [(1,), (None,), (2,)]
#    3005 """  # noqa: E501
#    3006 from pandas.io import sql
# -> 3008 return sql.to_sql(
#    3009     self,
#    3010     name,
#    3011     con,
#    3012     schema=schema,
#    3013     if_exists=if_exists,
#    3014     index=index,
#    3015     index_label=index_label,
#    3016     chunksize=chunksize,
#    3017     dtype=dtype,
#    3018     method=method,
#    3019 )
#
# File ~/Projects/stock_app/stockapp/lib/python3.11/site-packages/pandas/io/sql.py:788, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     783     raise NotImplementedError(
#     784         "'frame' argument should be either a Series or a DataFrame"
#     785     )
#     787 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 788     return pandas_sql.to_sql(
#     789         frame,
#     790         name,
#     791         if_exists=if_exists,
#     792         index=index,
#     793         index_label=index_label,
#     794         schema=schema,
#     795         chunksize=chunksize,
#     796         dtype=dtype,
#     797         method=method,
#     798         engine=engine,
#     799         **engine_kwargs,
#     800     )
#
# File ~/Projects/stock_app/stockapp/lib/python3.11/site-packages/pandas/io/sql.py:1948, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1898 """
#    1899 Write records stored in a DataFrame to a SQL database.
#    1900
#    (...)
#    1944     Any additional kwargs are passed to the engine.
#    1945 """
#    1946 sql_engine = get_engine(engine)
# -> 1948 table = self.prep_table(
#    1949     frame=frame,
#    1950     name=name,
#    1951     if_exists=if_exists,
#    1952     index=index,
#    1953     index_label=index_label,
#    1954     schema=schema,
#    1955     dtype=dtype,
#    1956 )
#    1958 total_inserted = sql_engine.insert_records(
#    1959     table=table,
#    1960     con=self.con,
#    (...)
#    1967     **engine_kwargs,
#    1968 )
#    1970 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/Projects/stock_app/stockapp/lib/python3.11/site-packages/pandas/io/sql.py:1852, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1840             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1842 table = SQLTable(
#    1843     name,
#    1844     self,
#    (...)
#    1850     dtype=dtype,
#    1851 )
# -> 1852 table.create()
#    1853 return table
#
# File ~/Projects/stock_app/stockapp/lib/python3.11/site-packages/pandas/io/sql.py:927, in SQLTable.create(self)
#     925 if self.exists():
#     926     if self.if_exists == "fail":
# --> 927         raise ValueError(f"Table '{self.name}' already exists.")
#     928     if self.if_exists == "replace":
#     929         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'Company Name.NS' already exists.
